# %%
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# **Polynomial Regression**
#
# If your data points clearly will not fit a linear regression (a straight line through all data points), it might be ideal for polynomial regression.
#
# Polynomial regression, like linear regression, uses the relationship between the variables x and y to find the best way to draw a line through the data points.

# %% [markdown]
# ****Polynomial Regression kya hota hai?****
#
# Polynomial Regression ek advanced version hoti hai Linear Regression ki.
#
# Linear Regression ek straight line fit karti hai data points par.
# (Equation: y=mx+c )
#
# Lekin agar data curve shape ma ho (upar-neeche hota hai), toh straight line fit nahi hoti.
# Is situation ma hum Polynomial Regression use kartay hain.
#
# Polynomial regression ek curve (polynomial function) fit karti hai data pe:
#
# y=b0+b1x+b2x^2+b3x^3+…
#
# Degree jitni zyada hogi (2, 3, 4 …), utna hi curve flexible hoga.

# %% [markdown]
# **How Does it Work?**
#
# Python has methods for finding a relationship between data-points and to draw a line of polynomial regression. We will show you how to use these methods instead of going through the mathematic formula.
#
# In the example below, we have registered 18 cars as they were passing a certain tollbooth.
#
# We have registered the car's speed, and the time of day (hour) the passing occurred.
#
# The x-axis represents the hours of the day and the y-axis represents the speed:

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]


mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %% [markdown]
# **Example Explained**

# %% [markdown]
# **numpy.polyfit(x, y, 3)**
#
# Yahan "3" ka matlab hai 3rd degree polynomial fit karna (yaani cubic curve).
#
# Ye function ek curve fit karega jiska equation kuch aisa hoga:
#
# 𝑦=
# 𝑎
# 3
# 𝑥^
# 3
# +
# 𝑎
# 2
# 𝑥^
# 2
# +
# 𝑎
# 1
# 𝑥
# +
# 𝑎
# 0
#
#
# Aur coefficients (a_3, a_2, a_1, a_0) automatically calculate kar dega.

# %% [markdown]
# **numpy.poly1d(...)**
#
# Ye coefficients ko ek polynomial model bana deta hai — jisko directly use karke hum y predict kar sakte hain.
#
# Example:
#
# mymodel(10)   # x = 10 par predicted speed kya hai

# %% [markdown]
# **numpy.linspace(1, 22, 100)**
#
# Ye line smooth banata hai — matlab 1 se 22 tak ke 100 equally spaced points.

# %% [markdown]
# **R-Squared**
#
# It is important to know how well the relationship between the values of the x- and y-axis is, if there are no relationship the polynomial regression can not be used to predict anything.
#
# The relationship is measured with a value called the r-squared.
#
# The r-squared value ranges from 0 to 1, where 0 means no relationship, and 1 means 100% related.
#
# Python and the Sklearn module will compute this value for you, all you have to do is feed it with the x and y arrays:

# %%
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

print(r2_score(y, mymodel(x)))
# Out:
# 0.9432150416451027

# %% [markdown]
# **Predict Future Values**
#
# Now we can use the information we have gathered to predict future values.
#
# Example: Let us try to predict the speed of a car that passes the tollbooth at around the time 17:00:
#
# To do so, we need the same mymodel array from the example above:

# %%
mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269697987

# %% [markdown]
# The example predicted a speed to be 88.87, which we also could read from the above diagram:

# %% [markdown]
# **Bad Fit?**
#
# Let us create an example where polynomial regression would not be the best method to predict future values.

# %%
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(2, 95, 100)

print(r2_score(y, mymodel(x)))
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
# Out:
# 0.009952707566680652
